# %%
import pandas as pd

# %% [markdown]
# 1 - Read CSV file from a website

# %% [markdown]
# Website - https://fixturedownload.com/sport/american-football

# %%
# reading CSV file from the website

df_az21 = pd.read_csv('https://fixturedownload.com/download/nfl-2021-arizona-cardinals-UTC.csv')

# %%
#df_az21

# %%
df_az21[['home_score', 'away_score']] = df_az21['Result'].str.split(" - ", expand=True)

# %%
df_az21
# Out:
#     Match Number     Round Number              Date             Location  \
# 0             12                1  12/09/2021 17:00       Nissan Stadium
# 1             21                2  19/09/2021 20:05   State Farm Stadium
# 2             46                3  26/09/2021 17:00      TIAA Bank Field
# 3             54                4  03/10/2021 20:05         SoFi Stadium
# 4             67                5  10/10/2021 20:25   State Farm Stadium
# 5             85                6  17/10/2021 20:05  FirstEnergy Stadium
# 6             97                7  24/10/2021 20:25   State Farm Stadium
# 7            122                8  29/10/2021 00:20   State Farm Stadium
# 8            126                9  07/11/2021 21:25       Levi's Stadium
# 9            142               10  14/11/2021 21:05   State Farm Stadium
# 10           153               11  21/11/2021 21:25          Lumen Field
# 11           191               13  05/12/2021 18:00        Soldier Field
# ...
